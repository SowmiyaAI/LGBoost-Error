# %%
# !pip install lightgbm--upgrade
# !pip install lightgbm==3.2.0
import pandas as pd
# Out:
# ERROR: Could not find a version that satisfies the requirement lightgbm--upgrade (from versions: none)
# ERROR: No matching distribution found for lightgbm--upgrade
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting lightgbm==3.2.0
#   Downloading lightgbm-3.2.0-py3-none-win_amd64.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 111.9 kB/s eta 0:00:00
# Requirement already satisfied: wheel in c:\users\new\anaconda3\lib\site-packages (from lightgbm==3.2.0) (0.33.6)
# Requirement already satisfied: numpy in c:\users\new\anaconda3\lib\site-packages (from lightgbm==3.2.0) (1.16.5)
# Requirement already satisfied: scipy in c:\users\new\anaconda3\lib\site-packages (from lightgbm==3.2.0) (1.3.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in c:\users\new\anaconda3\lib\site-packages (from lightgbm==3.2.0) (1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\new\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm==3.2.0) (0.13.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\new\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm==3.2.0) (3.1.0)
# Installing collected packages: lightgbm
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 4.3.0
#     Uninstalling lightgbm-4.3.0:
#       Successfully uninstalled lightgbm-4.3.0
# Successfully installed lightgbm-3.2.0
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
# Define LightGBM parameters
params = {
    'boosting': 'gbdt',
    'objective': 'binary',
    'metric': 'binary_logloss',  # You can use other metrics as well
    'num_leaves': 45,
    'learning_rate': 0.1,
    'max_depth': 5,
    'min_data_in_leaf': 20,
    'max_bin': 255,
    'bagging_fraction': 0.8,
    'feature_fraction': 0.8
}

# %%
from lightgbm import LGBMRegressor
regeressor=LGBMRegressor(params)
regeressor.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-666c9f096c9b> in <module>
#       1 from lightgbm import LGBMRegressor
#       2 regeressor=LGBMRegressor(params)
# ----> 3 regeressor.fit(x_train,y_train)
#
# ~\Anaconda3\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     820                     eval_init_score=eval_init_score, eval_metric=eval_metric,
#     821                     early_stopping_rounds=early_stopping_rounds, verbose=verbose, feature_name=feature_name,
# --> 822                     categorical_feature=categorical_feature, callbacks=callbacks, init_model=init_model)
#     823         return self
#     824
#
# ~\Anaconda3\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     686                               evals_result=evals_result, fobj=self._fobj, feval=eval_metrics_callable,
#     687                               verbose_eval=verbose, feature_name=feature_name,
# --> 688                               callbacks=callbacks, init_model=init_model)
#     689
#     690         if evals_result:
#
# ~\Anaconda3\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     226     # construct booster
#     227     try:
# --> 228         booster = Booster(params=params, train_set=train_set)
#     229         if is_valid_contain_train:
#     230             booster.set_train_data_name(train_data_name)
#
# ~\Anaconda3\lib\site-packages\lightgbm\basic.py in __init__(self, params, train_set, model_file, model_str, silent)
#    2227                 )
#    2228             # construct booster object
# -> 2229             train_set.construct()
#    2230             # copy the parameters from train_set
#    2231             params.update(train_set.get_params())
#
# ~\Anaconda3\lib\site-packages\lightgbm\basic.py in construct(self)
#    1470                                 init_score=self.init_score, predictor=self._predictor,
#    1471                                 silent=self.silent, feature_name=self.feature_name,
# -> 1472                                 categorical_feature=self.categorical_feature, params=self.params)
#    1473             if self.free_raw_data:
#    1474                 self.data = None
#
# ~\Anaconda3\lib\site-packages\lightgbm\basic.py in _lazy_init(self, data, label, reference, weight, group, init_score, predictor, silent, feature_name, categorical_feature, params)
#    1247                 params['categorical_column'] = sorted(categorical_indices)
#    1248
# -> 1249         params_str = param_dict_to_str(params)
#    1250         self.params = params
#    1251         # process for reference dataset
#
# ~\Anaconda3\lib\site-packages\lightgbm\basic.py in param_dict_to_str(data)
#     235         elif val is not None:
#     236             raise TypeError('Unknown type of parameter:%s, got:%s'
# --> 237                             % (key, type(val).__name__))
#     238     return ' '.join(pairs)
#     239
#
# TypeError: Unknown type of parameter:boosting_type, got:dict

# %%
y_pred=regeressor.predict(x_test)
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)
r_score
